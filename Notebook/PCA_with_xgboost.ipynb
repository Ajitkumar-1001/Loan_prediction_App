# %%
import sys
from pathlib import Path



project_root = Path().resolve().parent  
sys.path.append(str(project_root))

# %%
from App_files.data_loader import  target_feature , data_split
from App_files.dataframe_loader import df_loader
from visualizations.pca_plots import pca_scree_plot

from App_files.dim_red import Apply_pca, PCA_pipeline
from App_files.preprocessing_pipeline import preprocessing_pipeline 
from custom_experiments.experiment2 import pca_experiment_2
from App_files.feature_engineering import feature_engineered 

from config.config import logger
import os 
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
logger.info("Loading dataframe for manual testing of the 3NF dataframe with Machine Learning algorithms")
df = df_loader()
logger.info("Dataframe loaded successfully!")
# Out:
# 2025-07-15 22:07:27 | INFO | root | Loading dataframe for manual testing of the 3NF dataframe with Machine Learning algorithms
# 2025-07-15 22:07:27 | INFO | root | Creating Connection to the database
# 2025-07-15 22:07:27 | INFO | root | Connection created successfully
# 2025-07-15 22:07:27 | INFO | root | Creating tables
# 2025-07-15 22:07:27 | INFO | root | Tables created successfully
# 2025-07-15 22:07:27 | INFO | root | Loading the database and Normalizing for a 3NF..
# 2025-07-15 22:07:27 | INFO | root | Normalization done !.
# 2025-07-15 22:07:27 | INFO | root | Inserting data to the tables
# Removed exisiting database /Users/ajit/Desktop/loan_predictor_app/data/LoanDATABASE.db
# Connected to database: /Users/ajit/Desktop/loan_predictor_app/data/LoanDATABASE.db
# Table created successfully.
# Table created successfully.
# Table created successfully.
# Table created successfully.
# Table created successfully.
# Data inserted successfully.
# Data inserted successfully.
# 2025-07-15 22:07:27 | INFO | root | All data inserted successfully
# Data inserted successfully.
# Data inserted successfully.
# Data inserted successfully.
# 2025-07-15 22:07:28 | INFO | root | 🧹 Tables created, data inserted, and DB connection closed.
# 2025-07-15 22:07:28 | INFO | root | Dataframe loaded successfully!

# %%
X,y = target_feature(df)

# %%
Feature_Engineered_X = feature_engineered(X)

# %%
Preprocessor, Num_Features, Cat_Features = preprocessing_pipeline(Feature_Engineered_X)

# %%
processed_X = Preprocessor.fit_transform(Feature_Engineered_X)

# %%
if hasattr(processed_X, "toarray"):
    processed_X = processed_X.toarray()

# %%
X_train,X_test,y_train,y_test = data_split(processed_X,y)

# %%
pca_experiment_2(X_train,X_test,y_train,y_test)
# Out:
# 2025-07-15 22:10:07 | INFO | root | Training process Initiated for the custom experiment
# 2025/07/15 22:10:07 INFO mlflow.tracking.fluent: Experiment with name 'PCA custom experiment with XGBOOST' does not exist. Creating a new experiment.
# 2025-07-15 22:10:07 | INFO | root | MLflow setup initiated
# 2025-07-15 22:10:23 | INFO | root | PCA applied with shape: (16000, 4)
# 2025-07-15 22:10:26 | INFO | root | PCA applied with shape: (4000, 4)
# /Users/ajit/Desktop/loan_predictor_app/Loan_App/lib/python3.11/site-packages/xgboost/training.py:183: UserWarning: [22:10:26] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# 2025-07-15 22:10:26 | INFO | root | ✅ Logged PCA experiment with accuracy=0.9163 and f1=0.9153
# (0.91625, 0.9153186128553444)
