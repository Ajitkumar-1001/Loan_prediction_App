# %%
import sys
from pathlib import Path



project_root = Path().resolve().parent  
sys.path.append(str(project_root))

# %%
from App_files.data_loader import  target_feature
from App_files.dataframe_loader import df_loader
from visualizations.pca_plots import pca_scree_plot

from App_files.dim_red import Apply_pca, PCA_pipeline
from App_files.preprocessing_pipeline import preprocessing_pipeline 

from App_files.feature_engineering import feature_engineered 

from config.config import logger
import os 
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
logger.info("Loading dataframe for manual testing of the 3NF dataframe with Machine Learning algorithms")
df = df_loader()
logger.info("Dataframe loaded successfully!")
# Out:
# 2025-07-15 21:40:43 | INFO | root | Loading dataframe for manual testing of the 3NF dataframe with Machine Learning algorithms
# 2025-07-15 21:40:43 | INFO | root | Creating Connection to the database
# 2025-07-15 21:40:43 | INFO | root | Connection created successfully
# 2025-07-15 21:40:43 | INFO | root | Creating tables
# 2025-07-15 21:40:43 | INFO | root | Tables created successfully
# 2025-07-15 21:40:43 | INFO | root | Loading the database and Normalizing for a 3NF..
# 2025-07-15 21:40:43 | INFO | root | Normalization done !.
# 2025-07-15 21:40:43 | INFO | root | Inserting data to the tables
# Removed exisiting database /Users/ajit/Desktop/loan_predictor_app/data/LoanDATABASE.db
# Connected to database: /Users/ajit/Desktop/loan_predictor_app/data/LoanDATABASE.db
# Table created successfully.
# Table created successfully.
# Table created successfully.
# Table created successfully.
# Table created successfully.
# Data inserted successfully.
# Data inserted successfully.
# Data inserted successfully.
# Data inserted successfully.
# 2025-07-15 21:40:43 | INFO | root | All data inserted successfully
# 2025-07-15 21:40:44 | INFO | root | 🧹 Tables created, data inserted, and DB connection closed.
# 2025-07-15 21:40:44 | INFO | root | Dataframe loaded successfully!
# Data inserted successfully.

# %%
X,y = target_feature(df)

# %%
Feature_Engineered_X = feature_engineered(X)

# %%
Preprocessor, Num_Features, Cat_Features = preprocessing_pipeline(Feature_Engineered_X)

# %%
processed_X = Preprocessor.fit_transform(Feature_Engineered_X)

# %%
if hasattr(processed_X, "toarray"):
    processed_X = processed_X.toarray()

# %%
_,X_Pca = Apply_pca(processed_X)
# Out:
# 2025-07-15 21:41:05 | INFO | root | PCA applied with shape: (20000, 4)

# %%
X_Pca,Pca_model = PCA_pipeline(processed_X)
# Out:
# 2025-07-15 21:41:05 | INFO | root | Initiated experiment for the PCA
# 2025-07-15 21:41:24 | INFO | root | PCA applied with shape: (20000, 4)
# 2025-07-15 21:41:29 | INFO | root | Generating and logging Scree Plot...
# 2025-07-15 21:41:30 | INFO | root | Logged values for the PCA done!
# 🏃 View run PCA dim run at: https://dagshub.com/ajitkumarsenthil5/Loan_Approval_logs.mlflow/#/experiments/5/runs/fd8820f1f7914b60b0fb76cbb0a3d212
# 🧪 View experiment at: https://dagshub.com/ajitkumarsenthil5/Loan_Approval_logs.mlflow/#/experiments/5
